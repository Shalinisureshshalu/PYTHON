# %% [markdown]
# <a href="https://colab.research.google.com/github/Shalinisureshshalu/PYTHON/blob/main/Python_From_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(44)
# Out:
# 44

# %%
print('Hello World')
# Out:
# Hello World

# %%
n = input()
print(n)
# Out:
# 33
# 33

# %%
n = input()
print(n)
# Out:
# hi
# hi

# %%
n = int(input())
print(n)
# Out:
# 44
# 44

# %%
n = input()
print(n)
# Out:
# hello
# hello

# %%
a = int(input())
b = int(input())
sum = a+b
print(sum)
# Out:
# 10
# 20
# 30

# %%
total = 10
total += 20
print(total)
# Out:
# 30

# %%
a, b = map(int, input().split())
print(a+b)
# Out:
# 20 30
# 50

# %%
add = lambda X,Y :X+Y
X = int(input())
Y = int(input())
print(add(X,Y))
# Out:
# 20
# 40
# 60
